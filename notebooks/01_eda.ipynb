# %% [markdown]
# ## **Just a EDA Notebook for Credit Fraud Detection**
#
# ---
#
# Made this notebook to perform EDA on the dataset, to understand the following
#
# - Dataset structure
# - Transaction and identity information
# - Fraud distribution
# - Missing values
# - Numerical features

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/ieee-cis-fraud"
# Out:
# ls: cannot access '/content/drive/MyDrive/ieee-cis-fraud': No such file or directory
